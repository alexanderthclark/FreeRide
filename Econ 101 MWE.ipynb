# %%
import econ101 as econ
import matplotlib.pyplot as plt

# %% [markdown]
# # Define demand and supply curves

# %%
demand = econ.Demand(12,-2)

# %%
supply = econ.Supply(0,2)

# %% [markdown]
# # Solve for equilibrium and create equilibrium object

# %%
demand.equilibrium(supply)
# Out:
# (6.0, 3.0)

# %%
e = econ.Equilibrium(demand, supply)

# %%
e.p, e.q
# Out:
# (6.0, 3.0)

# %% [markdown]
# # Plot Equilibrium

# %%
fig, ax = plt.subplots()
e.plot(ax)
e.plot_clean(ax)
demand.plot_surplus(supply, ax)
ax.text(1,8, 'CS')
ax.text(1,4, 'PS')
# Out:
# Text(1, 4, 'PS')
